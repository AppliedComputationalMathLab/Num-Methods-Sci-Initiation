# %%
import numpy as np
import struct
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np

# %%
def f(x: np.float64) -> np.float64:
    return (x**10) + 1 - (x**10)

# %%
interval = [39.2, 42.4]
x = np.linspace(interval[0], interval[1], 1000)
y = f(x)

# %%
print(f"value = {(x[y == 2])}")
# Out:
# value = [39.40820821 39.41141141 39.42102102 39.42422422 39.44024024 39.44664665
#  39.46266266 39.46586587 39.46906907 39.47547548 39.47867868 39.48508509
#  39.48828829 39.4978979  39.52352352 39.52672673 39.53313313 39.53633634
#  39.53953954 39.54914915 39.55875876 39.56196196 39.56516517 39.57157157
#  39.57477477 39.58758759 39.59399399 39.6036036  39.60680681 39.61321321
#  39.61961962 39.62602603 39.64204204 39.64524525 39.64844845 39.65165165
#  39.65485485 39.66126126 39.67087087 39.68048048 39.68688689 39.69329329
#  39.6996997  39.71251251 39.71571572 39.71891892 39.72212212 39.72852853
#  39.74134134 39.74454454 39.75095095 39.75415415 39.77017017 39.77337337
#  39.7957958  39.798999   39.81181181 39.81501502 39.81821822 39.82142142
#  39.82782783 39.84064064 39.84384384 39.84704705 39.85985986 39.86306306
#  39.86626627 39.87587588 39.87907908 39.88228228 39.88548549 39.88868869
#  39.89189189 39.8950951  39.90790791 39.91111111 39.91431431 39.92072072
#  39.92712713 39.93353353 39.94314314 39.94634635 39.95915916 39.98478478
#  39.99119119 39.9975976  40.0008008  40.004004   40.00720721 40.01361361
#  40.01681682 40.02002002 40.03923924 40.04564565 40.05525526 40.05845846
#  40.06486486 40.08408408 40.09049049 40.09369369 40.10650651 40.11291291
#  40.11611612 40.12892893 40.13533534 40.13853854 40.14174174 40.15775776
#  40.16096096 40.16736737 40.17697698 40.18018018 40.18338338 40.18978979
#  40.1993994  40.2026026  40.20900901 40.21861862 40.22182182 40.22502503
#  40.22822823 40.23463463 40.25065065 40.25385385 40.25705706 40.26026026
#  40.26346346 40.26986987 40.27627628 40.28268268 40.3019019  40.30830831
#  40.31151151 40.32432432 40.32752753 40.33073073 40.33393393 40.33713714
#  40.34034034 40.34354354 40.34674675 40.35955956 40.36596597 40.36916917
#  40.37237237 40.37557558 40.38198198 40.38838839 40.39479479 40.397998
#  40.4012012  40.4044044  40.41081081 40.43003003 40.43643644 40.43963964
#  40.44604605 40.45245245 40.45565566 40.45885886 40.46206206 40.46526527
#  40.47167167 40.47487487 40.47807808 40.48128128 40.48448448 40.48768769
#  40.5005005  40.5037037  40.51011011 40.51331331 40.52292292 40.52932933
#  40.53573574 40.54534535 40.54854855 40.55495495 40.55815816 40.57417417
#  40.58058058 40.58698699 40.61261261 40.61581582 40.61901902 40.62542543
#  41.9035035  41.90670671 41.91311311 41.91631632 41.91951952 41.93553554
#  41.93873874 41.94514515 41.95155155 41.96116116 41.96436436 41.96756757
#  41.97397397 41.98998999 41.9995996  42.00920921 42.01561562 42.04444444
#  42.04764765 42.05085085 42.05405405 42.06046046 42.07007007 42.07327327
#  42.07967968 42.09249249 42.0956957  42.10530531 42.12452452 42.12772773
#  42.13093093 42.13733734 42.14374374 42.14694695 42.15975976 42.16616617
#  42.16936937 42.17897898 42.18218218 42.18538539 42.19499499 42.22062062]

# %%
mpl.rcParams['pdf.fonttype'] = 42
mpl.rcParams['ps.fonttype'] = 42

plt.plot(x, y, linewidth=1.3, color='#0077FFFF')
plt.xlim(interval[0], interval[1])

plt.xlabel('x', fontsize=14)
plt.ylabel('f(x) = (x^10 + 1) - x^10', fontsize=14)
plt.yticks(fontsize=12, rotation=0)
plt.xticks(fontsize=12, rotation=0)


centimeters_x = 30
centimeters_y = 11.5

inches_x = centimeters_x / 2.54
inches_y = centimeters_y / 2.54



plt.gcf().set_size_inches(inches_x, inches_y)

plt.grid(True, linewidth=1.0, alpha=1)

plt.savefig(
    "figs/NumError1.pdf",
    format='pdf',
    bbox_inches='tight',
)

# %% [markdown]
# Exemplo com 42.1

# %% [markdown]
# Valor exato = 42.1 ** 10 = 17.491.254.479.245.335,8346502201

# %%
# Valor representado
f"{42.1:.48f}"
# Out:
# '42.100000000000001421085471520200371742248535156250'

# %% [markdown]
# 42,100000000000001421085471520200371742248535156250

# %% [markdown]
# Logo 42.1 já não é representado exatamente, e sim como 42.100000000000001421085471520200371742248535156250, então as próximas operações já são realizadas como (42.100000000000001421085471520200371742248535156250)^10 e não 42.1^10

# %%
p = np.float64(17491254479245335.8346502201)
p
# Out:
# np.float64(1.7491254479245336e+16)

# %%
p1 = np.float64(42.1)**10
p1
# Out:
# np.float64(1.7491254479245342e+16)

# %%
p-p1
# Out:
# np.float64(-6.0)

# %%
def getBinary(x: np.float64):
    empacotado = struct.pack('>d', float(x))
    inteiro = int.from_bytes(empacotado, 'big')
    
    binario_puro = f"{inteiro:064b}"
    
    blocos = [binario_puro[i:i+4] for i in range(0, 64, 4)]
    
    return " ".join(blocos)

# %%
getBinary(42.1**10)
# Out:
# '0100 0011 0100 1111 0001 0010 0001 1010 0000 0100 1111 0100 1010 1000 0000 1111'

# %%
getBinary(42.1**10 + 1)
# Out:
# '0100 0011 0100 1111 0001 0010 0001 1010 0000 0100 1111 0100 1010 1000 0001 0000'

# %%
getBinary(42.1**10)
# Out:
# '0100 0011 0100 1111 0001 0010 0001 1010 0000 0100 1111 0100 1010 1000 0000 1111'
